# %%
import numpy as np
import numpy.matlib
import matplotlib.pyplot as plt
from pytictoc import TicToc

#차원 
D = 5

# 거리를 구할 기준점
z = np.random.randn(D)

# 샘플의 수에 대한 배열
Nset = np.array([10, 100, 1000, 10000, 100000, 1000000])

t = TicToc()
t1 = []
t2 = []

for N in Nset:
    X = np.random.rand(N, D)
    
    t.tic()
    dist1 = np.zeros(N)
    for n in range(0,N):
        dist1[n] = np.sqrt(np.sum((X[n,:] - z)**2)) #BLANK1
    t.toc()
    t1 = np.append(t1, t.tocvalue())

    t.tic()
    Z = np.matlib.repmat(z.reshape((1,D)), N, 1)
    dist1 = np.sqrt(np.sum( (X - Z)**2, axis = 1 ))  # BLANK2
    t.toc()
    t2 = np.append(t2, t.tocvalue())
# Out:
# Elapsed time is 0.000429 seconds.
# Elapsed time is 0.001246 seconds.
# Elapsed time is 0.000571 seconds.
# Elapsed time is 0.000023 seconds.
# Elapsed time is 0.006743 seconds.
# Elapsed time is 0.000320 seconds.
# Elapsed time is 0.056702 seconds.
# Elapsed time is 0.000583 seconds.
# Elapsed time is 0.562620 seconds.
# Elapsed time is 0.004367 seconds.
# Elapsed time is 5.637086 seconds.
# Elapsed time is 0.047094 seconds.

# %%
 plt.figure(figsize = (5, 5))
plt.plot(Nset, 1e3*t1)
plt.plot(Nset, 1e3*t2)
plt.xlabel("number of samples")
plt.ylabel("computation time [ms]")
plt.xscale("log")
plt.yscale("log")
plt.legend({'blank1','blank2'})
plt.savefig('code.eps')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
