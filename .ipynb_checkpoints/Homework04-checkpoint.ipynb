# %%
import numpy as np
import pandas as pd
import numpy.matlib
import math

# two-class classification
data_red = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-red.csv', dtype = None, delimiter=';')
data_white = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-white.csv', dtype = None, delimiter=';')

# %%
from sklearn import svm
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

# pandas class -> numpy ndarray로 바꾸기
X0 = data_red.to_numpy()
X1 = data_white.to_numpy()

N0,D = X0.shape
N1,D = X1.shape

# target value
t0 = np.zeros(N0, dtype = int) # red wine = 0
t1 = np.ones(N1, dtype = int) # white wine = 1

# 전체 dataset
X = np.vstack((X0, X1)) # input, 12차원의 입력
t = np.hstack((t0, t1)) # output, {0, 1} 구분, two-class

# normalization, 
Xmin = np.min(X, axis = 0)
Xmax = np.max(X, axis = 0)
X = (X - Xmin) / (Xmax - Xmin)
# X ~ [0, 1]

N,D = X.shape
print(X.shape)

# %%
C = np.cov(X) # X = D x N, C = D x D
print(C.shape)

U, s, V = np.linalg.svd(C, full_matrices = True)
# C = U * diag(s) * V
# 우리가 아는 꼴로 만들기 위한 작업 2개
S = np.diag(s)
V = V.T


#for Dim in range(2,12):


    


u1 = U[:,0]
u2 = U[:,1]
s1 = s[0]
s2 = s[1]

plt.figure()
ax = plt.subplot(1,1,1)
plt.scatter(X[0,:], X[1,:], c = 'gray', s = 10)
ax.set_aspect('equal')

plt.plot([0, s1*u1[0]], [0, s1*u1[1]])
plt.plot([0, s2*u2[0]], [0, s2*u2[1]])






model1 = svm.SVC(kernel = 'rbf') # radial basis function
model2 = LogisticRegression()

# test-size를 20퍼로 하겠다
X_train, X_test, t_train, t_test = train_test_split(X, t, test_size = 0.20)

N_train,D_train = X_train.shape
N_test,D_test = X_test.shape

# 학습
model1.fit(X_train, t_train)
model2.fit(X_train, t_train)

# 예측
t1_train = model1.predict(X_train)
t2_train = model2.predict(X_train)
t1_test = model1.predict(X_test)
t2_test = model2.predict(X_test)

# accuracy
# t_train # 정답, 학습데이터
# t1_train # 예측, 학습데이터, SVM
# t2_train # 예측, 학습데이터, Logistic

print(np.sum(t_train == t1_train) / N_train ) # SVM, 학습데이터
print(np.sum(t_test  == t1_test)  / N_test  ) # SVM, 테스트셋

print(np.sum(t_train == t2_train) / N_train ) # logistic, 학습데이터
print(np.sum(t_test  == t2_test)  / N_test  ) # logistic, 테스트셋
# Out:
# (6497, 6497)
