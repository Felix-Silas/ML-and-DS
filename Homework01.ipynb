# %%
import numpy as np
import numpy.matlib
import matplotlib.pyplot as plt
from pytictoc import TicToc

D = 5

z = np.random.randn(D)

Nset = np.array([10, 100, 1000, 10000, 100000, 1000000])

t = TicToc()
t1 = []
t2 = []

for N in Nset:
    X = np.random.rand(N, D)
    
    t.tic()
    dist1 = np.zeros(N)
    for n in range(0,N):
        dist1[n] = np.sqrt(np.sum((X[n,:] - z)**2)) #BLANK1
    t.toc()
    t1 = np.append(t1, t.tocvalue())

    t.tic()
    Z = np.matlib.repmat(z.reshape((1,D)), N, 1)
    dist1 = np.sum( (X - Z)**2, axis = 1 )  # BLANK2
    t.toc()
    t2 = np.append(t2, t.tocvalue())
# Out:
# Elapsed time is 0.000396 seconds.
# Elapsed time is 0.001230 seconds.
# Elapsed time is 0.000581 seconds.
# Elapsed time is 0.000056 seconds.
# Elapsed time is 0.006694 seconds.
# Elapsed time is 0.000205 seconds.
# Elapsed time is 0.057512 seconds.
# Elapsed time is 0.000595 seconds.
# Elapsed time is 0.576720 seconds.
# Elapsed time is 0.004312 seconds.
# Elapsed time is 5.818961 seconds.
# Elapsed time is 0.045744 seconds.

# %%
 plt.figure(figsize = (5, 5))
plt.plot(Nset, 1e3*t1)
plt.plot(Nset, 1e3*t2)
plt.xlabel("number of samples")
plt.ylabel("computation time [ms]")
plt.xscale("log")
plt.yscale("log")
plt.legend({'blank1','blank2'})
plt.savefig('code.eps')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
